# %% [markdown]
# # Lab 05: Scoring & Ranking - Exercise
#
# **Total Points:** 100 | **Time:** ~45 minutes
#
# ---

# %% [markdown]
# ## Exercise 1: Calculate Score (25 pts)
#
# Create `get_score(query, text)` that returns how many times query appears (case-insensitive).

# %%
# YOUR CODE HERE
def get_score(query, text):
    pass

# Check your answer
print(f"Test 1: {get_score('fever', 'fever and high fever')}")
print(f"Test 2: {get_score('rash', 'no match here')}")

# %%
# Quick check (structure only)
result = get_score('test', 'test test test')
if result is not None:
    print(f'✅ Function returns a value')
    if isinstance(result, int):
        print(f'✅ Function returns an integer')
    else:
        print(f'❌ Function should return an integer')
else:
    print(f'❌ Function returns None')

# %% [markdown]
# ---
#
# ## Exercise 2: Sort Documents by Score (25 pts)
#
# Given `scored_list`, sort it by score descending. Store in `sorted_docs`.

# %%
scored_list = [
    {'score': 1, 'text': 'Doc A'},
    {'score': 3, 'text': 'Doc B'},
    {'score': 2, 'text': 'Doc C'}
]

# YOUR CODE HERE
sorted_docs = None

# Check your answer
print(sorted_docs)

# %%
# Quick check (structure only)
if sorted_docs is not None:
    print(f'✅ sorted_docs has a value')
    if isinstance(sorted_docs, list):
        print(f'✅ sorted_docs is a list')
        print(f'   Number of items: {len(sorted_docs)}')
        if len(sorted_docs) >= 2:
            if sorted_docs[0]['score'] >= sorted_docs[1]['score']:
                print(f'✅ List appears to be sorted descending')
            else:
                print(f'❌ List should be sorted by score descending')
    else:
        print(f'❌ sorted_docs should be a list')
else:
    print(f'❌ sorted_docs is still None')

# %% [markdown]
# ---
#
# ## Exercise 3: Top-K Function (25 pts)
#
# Create `top_k(items, k)` that returns first k items from a list.

# %%
# YOUR CODE HERE
def top_k(items, k):
    pass

# Check your answer
print(f"Test: {top_k([1, 2, 3, 4, 5], 3)}")

# %%
# Quick check (structure only)
result = top_k([1, 2, 3, 4, 5], 3)
if result is not None:
    print(f'✅ Function returns a value')
    if isinstance(result, list):
        print(f'✅ Function returns a list')
        print(f'   Number of items: {len(result)}')
    else:
        print(f'❌ Function should return a list')
else:
    print(f'❌ Function returns None')

# %% [markdown]
# ---
#
# ## Exercise 4: Search and Rank (25 pts)
#
# Create `search_rank(query, docs, k)` that returns top k scored documents.
#
# Return format: `[{'text': doc, 'score': score}, ...]` sorted by score descending.

# %%
documents = [
    'Rubella causes fever',
    'Dengue fever fever symptoms',
    'Cholera causes diarrhea',
    'Malaria fever treatment'
]

# YOUR CODE HERE
def search_rank(query, docs, k):
    pass

# Check your answer
results = search_rank('fever', documents, 2)
print(results)

# %%
# Quick check (structure only)
results = search_rank('fever', documents, 2)
if results is not None:
    print(f'✅ Function returns a value')
    if isinstance(results, list):
        print(f'✅ Function returns a list')
        print(f'   Number of results: {len(results)}')
        if len(results) > 0 and isinstance(results[0], dict):
            if 'score' in results[0] and 'text' in results[0]:
                print(f'✅ Results have correct structure')
            else:
                print(f'❌ Each result should have "score" and "text" keys')
        else:
            print(f'❌ Results should be list of dictionaries')
    else:
        print(f'❌ Function should return a list')
else:
    print(f'❌ Function returns None')

# %% [markdown]
# ---
#
# ## 🎉 Finished!
#
# ### Summary:
# | Exercise | Skill |
# |----------|-------|
# | 1 | Calculate relevance score |
# | 2 | Sort by score |
# | 3 | Get top K results |
# | 4 | Complete search & rank |
#
# ### Submit:
# ```bash
# git add . && git commit -m 'Complete Lab 05' && git push
# ```
#
# Check your score in GitHub Actions tab!
